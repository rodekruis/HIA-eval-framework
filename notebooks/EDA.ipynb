# %% [markdown]
# # Exploratory Data Analysis (raw output of DeepEval's synthesizer)

# %% [markdown]
# ### The purpose of this notebook is to perform exploratory data analysis on the synthetic dataset generated using DeepEval's synthesizer (generate_goldens_from_contexts function). The output was not modified in any way. Any later additions to the dataset are not included in this version.

# %%
# imports
import pandas as pd
import numpy as np
from rich import print

# %%
# load data
data = pd.read_csv(r"C:\Users\dari\Desktop\grad project 2026\HIA-eval-framework\synthetic_data\20260318_100246.csv")
print(data.head())
# Out:
#                                                input  actual_output  \
# 0  Which websites list NL support orgs and shelte...            NaN
# 1  How does a Dublin claim restrict NL asylum see...            NaN
# 2  Analyze the heightened exploitation risks face...            NaN
# 3  Explain LVV’s full form, its 18-month shelter ...            NaN
# 4  What are the eligibility criteria for undocume...            NaN
#
#                                      expected_output  \
# 0  You can find information about support organiz...
# 1  A Dublin claim restricts NL asylum seekers’ ac...
# 2                                                NaN
# 3  LVV stands for Landelijke Vreemdelingen Voorzi...
# 4  After 2025, access to LVV (Landelijke Vreemdel...
#
#                                              context  source_file
# 0  Q: What are relevant websites with information...          NaN
# 1  Q: What are relevant websites with information...          NaN
# 2  Q: What are relevant websites with information...          NaN
# 3  Q: What are relevant websites with information...          NaN
# 4  Q: What are relevant websites with information...          NaN

# %%
print(data.info())
print(data.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   input            102 non-null    object
#  1   actual_output    0 non-null      float64
#  2   expected_output  101 non-null    object
#  3   context          102 non-null    object
#  4   source_file      0 non-null      float64
# dtypes: float64(2), object(3)
# memory usage: 4.1+ KB
# None
# Index(['input', 'actual_output', 'expected_output', 'context', 'source_file'], dtype='object')

# %% [markdown]
# The columns actual_output and source_file are entirely empty since this is a pre-evaluation test set (actual outputs get populated once we run the chatbot against it).

# %% [markdown]
# ----

# %% [markdown]
# The column expected_output has one null value.

# %%
print(data[data.isnull()])
# Out:
#     input  actual_output expected_output context  source_file
# 0     NaN            NaN             NaN     NaN          NaN
# 1     NaN            NaN             NaN     NaN          NaN
# 2     NaN            NaN             NaN     NaN          NaN
# 3     NaN            NaN             NaN     NaN          NaN
# 4     NaN            NaN             NaN     NaN          NaN
# ..    ...            ...             ...     ...          ...
# 97    NaN            NaN             NaN     NaN          NaN
# 98    NaN            NaN             NaN     NaN          NaN
# 99    NaN            NaN             NaN     NaN          NaN
# 100   NaN            NaN             NaN     NaN          NaN
# 101   NaN            NaN             NaN     NaN          NaN
#
# [102 rows x 5 columns]
