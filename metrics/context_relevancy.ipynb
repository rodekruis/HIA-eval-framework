# %%
import os
import pandas as pd
import numpy as np
from rich import print
import ast
from deepeval import evaluate
from deepeval.test_case import LLMTestCase
from deepeval.metrics import ContextualRelevancyMetric
from dotenv import load_dotenv, dotenv_values
from deepeval.models import AzureOpenAIModel

# %%
goldens = pd.read_csv("../synthetic_data/goldens.csv")

# %%
endpoint = "https://510-ai-research.openai.azure.com/"
model = "gpt-4.1"
deployment = "gpt-4.1-students"

# loading variables from .env file
load_dotenv(r"C:\Users\dari\Desktop\grad project 2026\HIA-eval-framework\.env")
subscription_key = os.getenv("azure_subscription_key")
api_version = "2024-12-01-preview"

# custom model
custom_model = AzureOpenAIModel(
  model=deployment,
  api_key=subscription_key,
  azure_endpoint=endpoint,
  api_version=api_version,
  deployment_name=deployment
)

# %%
actual_output = goldens['expected_output'][0]
expected_output = goldens['expected_output'][0]

retrieval_context = ast.literal_eval(goldens['context'][0])

metric = ContextualRelevancyMetric(
    threshold=0.7,
    include_reason=True,
    model = custom_model,
)
test_case = LLMTestCase(
    input="Where can I find info about support orgs and shelters for UM, incl. local options?",
    actual_output=actual_output,
    expected_output=expected_output,
    retrieval_context=retrieval_context
)

# To run metric as a standalone
# metric.measure(test_case)
# print(metric.score, metric.reason)

evaluate(test_cases=[test_case], metrics=[metric])
# Out:
# ✨ You're running DeepEval's latest Contextual Relevancy Metric! (using gpt-4.1-students (Azure), strict=False,
# async_mode=True)...
# c:\Users\dari\conda\envs\hia\Lib\site-packages\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter
# support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Relevancy (score: 0.8205128205128205, threshold: 0.7, strict: False, evaluation model: gpt-4.1-students (Azure), reason: The score is 0.82 because, although many statements are irrelevant (e.g., 'does not provide information about support organizations or shelters for UM'), there are several highly relevant statements such as 'On the website of LOS you can find information about support organizations' and 'On the website Helpful Information from the Red Cross you can find information about local organizations in different cities.' This mix justifies a strong but not perfect score., error: None)
#
# For test case:
#
#   - input: Where can I find info about support orgs and shelters for UM, incl. local options?
#   - actual output: You can find information about support organizations and shelters for undocumented migrants (UM), including local options, on the Stichting LOS website: https://www.stichtinglos.nl/content/organisaties and for shelters: https://www.stichtinglos.nl/noodopvang. Additionally, the Red Cross Helpful Information website provides details about local organizations in different cities: https://helpfulinformation.redcross.nl/.
#   - expected output: You can find information about support organizations and shelters for undocumented migrants (UM), including local options, on the Stichting LOS website: https://www.stichtinglos.nl/content/organisaties and for shelters: https://www.stichtinglos.nl/noodopvang. Additionally, the Red Cross Helpful Information website provides details about local organizations in different cities: https://helpfulinformation.redcross.nl/.
#   - context: None
#   - retrieval context: ['Q: What are relevant websites with information about / for UM? A: \n* On the website of **LOS** you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang. \n* On the website **Helpful Information** from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/', 'Q: Why is somebody that is undocumented often in a vulnerable position? A: Undocumented migrants are regarded as a vulnerable group within society. They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations. Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.\n\nAlso, they are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet). They have only a very limited right to assistance and facilities from the government and other agencies. As a result, they can easily get into trouble. The Red Cross provides help to everyone, including undocumented migrants.', 'Q: When is somebody undocumented? A: An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa has expired, or they may never have had one. \n\nThey are mainly migrants who:\n- have had their residence application rejected, for example asylum seekers whose application for asylum has been rejected;\n- have not applied for a residence permit, either for regular residence or asylum;\n- are victims of human trafficking;\n- do not have a work permit, for example domestic workers.\n\nEU citizens do not need to apply for a residence permit to be in the Netherlands legally. Migrants from the EU can therefore never be undocumented."\n', "Q: What is a Dublin claim? A: When somebody asks asylum in the Netherlands, their finger prints will be checked in an EU database. If their fingerprint is registered in another EU country, that country is responsible for proceeding the asylum procedure. In that case somebody gets a Dublin claim and has to return to the EU country where the fingerprint was taken. They cannot get asylum in the Netherlands. This is because according to the EU’s Dublin Regulation, somebody's asylum procedure must be carried out in the first country of arrival. \n\nThe Dublin claim ends after 18 months. So if somebody is capable of staying under the radar for 18 months, then he/ she can request asylum in the Netherlands.\n\nIt is very hard for people with a Dublin Claim to get support. For example often local shelter programs do not provide shelter to people with a Dublin claim.", 'Q: Where can I find information about the programs of the Red Cross for Undocumented Migrants? A: As Red Cross we provide workshops to UM about health care, working rights, healthy habits, clear communication and first aid. We also have a [website](https://helpfulinformation.redcross.nl) with information about local aid organizations and we help people through our WhatsApp Helpline. Besides that people that are UM can also be in our food program or shelter program. This is always through the connection with a partner organization. For more information on our programs, you can have a look at our website: https://www.rodekruis.nl/wat-doen-wij/hulp-in-nederland/ondersteuning-ongedocumenteerde-migranten/', 'Q: Where can I find information about the shelter rights for Undocumented Migrants? A: You can find information about different shelter rights on the website of Stichting Los: https://www.stichtinglos.nl/content/opvang-en-onderdak\n\nIn general people have the right to rent a house, but not from social corperate housing. There is no general right for  ...
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Contextual Relevancy: 100.00% pass rate
#
# ======================================================================
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=565296;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 5.15s | token cost: None)
# » Test Results (1 total tests):
#    » Pass Rate: 100.0% | Passed: 1 | Failed: 0
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.
# EvaluationResult(test_results=[TestResult(name='test_case_0', success=True, metrics_data=[MetricData(name='Contextual Relevancy', threshold=0.7, success=True, score=0.8205128205128205, reason="The score is 0.82 because, although many statements are irrelevant (e.g., 'does not provide information about support organizations or shelters for UM'), there are several highly relevant statements such as 'On the website of LOS you can find information about support organizations' and 'On the website Helpful Information from the Red Cross you can find information about local organizations in different cities.' This mix justifies a strong but not perfect score.", strict_mode=False, evaluation_model='gpt-4.1-students (Azure)', error=None, evaluation_cost=None, verbose_logs='Verdicts:\n[\n    {\n        "verdicts": [\n            {\n                "statement": "On the website of LOS you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang.",\n                "verdict": "yes",\n                "reason": null\n            },\n            {\n                "statement": "On the website Helpful Information from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/",\n                "verdict": "yes",\n                "reason": null\n            }\n        ]\n    },\n    {\n        "verdicts": [\n            {\n                "statement": "Undocumented migrants are regarded as a vulnerable group within society. They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations. Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.",\n                "verdict": "no",\n                "reason": "This statement explains why undocumented migrants are vulnerable, but does not provide information about support organizations or shelters for UM, nor local options."\n            },\n            {\n                "statement": "They are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet). They have only a very limited right to assistance and facilities from the government and other agencies. As a result, they can easily get into trouble.",\n                "verdict": "no",\n                "reason": "This statement discusses legal limitations and risks for undocumented migrants, but does not mention support organizations, shelters, or where to find information about them."\n            },\n            {\n                "statement": "The Red Cross provides help to everyone, including undocumented migrants.",\n                "verdict": "yes",\n                "reason": null\n            }\n        ]\n    },\n    {\n        "verdicts": [\n            {\n                "statement": "An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa has expired, or they may never have had one.",\n                "verdict": "no",\n                "reason": "This statement explains the definition of an undocumented migrant, but does not provide information about support organizations or shelters for UM (undocumented migrants), nor does it mention where to find such information."\n            },\n            {\n                "statement": "They are mainly migrants who: have had their residence application rejected, for example asylum seekers whose application for asylum has been rejected; have not applied for a residence permit, either for regular residence or asylum; are victims of human trafficking; do not have a work permit, for example domestic workers.",\n                "verdict": "no",\n            ...

# %%
metric = ContextualRelevancyMetric(
    threshold=0.7,
    include_reason=True,
    model = custom_model,
)

test_cases = []
for i in range(len(goldens)):
    tc = LLMTestCase(
        input=goldens['input'][i],
        actual_output=goldens['expected_output'][i],
        expected_output=goldens['expected_output'][i],
        retrieval_context=ast.literal_eval(goldens['context'][i]),
        context=ast.literal_eval(goldens['context'][i])
    )
    test_cases.append(tc)

print(f"Built {len(test_cases)} test cases")
print(f"First input: {test_cases[0].input[:80]}...")
# Out:
# Built 102 test cases
# First input: Where can I find info about support orgs and shelters for UM, incl. local option...

# %%
evaluate(test_cases=test_cases, metrics=[ metric])
# Out:
# ✨ You're running DeepEval's latest Contextual Relevancy Metric! (using gpt-4.1-students (Azure), strict=False,
# async_mode=True)...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Contextual Relevancy (score: 0.6739130434782609, threshold: 0.7, strict: False, evaluation model: gpt-4.1-students (Azure), reason: The score is 0.67 because, although the relevant statements highlight that 'undocumented migrants are regarded as a vulnerable group within society' and face risks like 'exploitation at the hands of bad employers, slum landlords or human traffickers' and 'housing is a very big challenge,' most of the retrieval context only provides procedural information or resources, which 'does not address the risks UM might face if they lost access to all support orgs.', error: None)
#
# For test case:
#
#   - input: If UM lost access to all support orgs, what new risks might they face in NL?
#   - actual output: If undocumented migrants (UM) lose access to all support organizations in the Netherlands, they face increased risks of exploitation by bad employers, slum landlords, or human traffickers due to their vulnerable position and lack of rights. Without support, they have even less access to shelter, healthcare, and basic needs, making them more likely to end up in unsafe or unhealthy situations. They are also not entitled to social benefits or health insurance, so losing support further limits their ability to get help, increasing the likelihood of homelessness, health problems, and social isolation.
#   - expected output: If undocumented migrants (UM) lose access to all support organizations in the Netherlands, they face increased risks of exploitation by bad employers, slum landlords, or human traffickers due to their vulnerable position and lack of rights. Without support, they have even less access to shelter, healthcare, and basic needs, making them more likely to end up in unsafe or unhealthy situations. They are also not entitled to social benefits or health insurance, so losing support further limits their ability to get help, increasing the likelihood of homelessness, health problems, and social isolation.
#   - context: ['Q: What are relevant websites with information about / for UM? A: \n* On the website of **LOS** you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang. \n* On the website **Helpful Information** from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/', 'Q: Why is somebody that is undocumented often in a vulnerable position? A: Undocumented migrants are regarded as a vulnerable group within society. They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations. Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.\n\nAlso, they are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet). They have only a very limited right to assistance and facilities from the government and other agencies. As a result, they can easily get into trouble. The Red Cross provides help to everyone, including undocumented migrants.', 'Q: When is somebody undocumented? A: An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa has expired, or they may never have had one. \n\nThey are mainly migrants who:\n- have had their residence application rejected, for example asylum seekers whose application for asylum has been rejected;\n- have not applied for a residence permit, either for regular residence or asylum;\n- are victims of human trafficking;\n- do not have a work permit, for example domestic workers.\n\nEU citizens do not need to apply for a residence permit to be in the Netherlands legally. Migrants from the EU can therefore never be undocumented."\n', "Q: What is a Dublin claim? A: When somebody asks asylum in the Netherlands, their finger prints will be checked in an EU database. If their fingerprint is registered in another EU country, that country is responsible for proceeding the asylum procedure. In that case somebody gets a Dublin claim and has to return to the EU country where the fingerprint was taken. They cannot get asylum in the Netherlands. This is because according to the EU’s Dublin Regulation, somebody's asylum procedure must be carried out in the first country of arrival. \n\nThe Dublin claim ends after 18 months. So if somebody is capable of staying under the radar for 18 months, then he/ she can request asylum in the Netherlands.\n\nIt is very hard for people with a Dublin Claim to get support. For example often local shelter programs do not provide shelter to people with a Dublin claim.", 'Q: Where can I find information about the programs of the Red Cross for Undocumented Migrants? A: As Red Cross we provide workshops to UM about health care, working rights, healthy habits, clear communication and first aid. We also have a [website](https://helpfulinformation.redcross.nl) with information about local aid organizations and we help people through our WhatsApp Helpline. Besides that people that are UM can also be in our food program or shelter program. This is always through the connection with a partner organization. For more information on our programs, you can have a look at our website: https://www.rodekruis.nl/wat-doen-wij/hulp-in-nederland/ondersteuning-ongedocumenteerde-migranten/', 'Q: Where can I find information about the shelter rights for Undocumented Migrants? A: You can find information about different shelter rights on the website of Stichting Los: https://www.stichtinglos.nl/content/opvang-en-onderdak\n\nIn general people have the right to rent a house, but not from social corperate housing. There is no general right for shelter fo ...
#   - retrieval context: ['Q: What are relevant websites with information about / for UM? A: \n* On the website of **LOS** you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang. \n* On the website **Helpful Information** from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/', 'Q: Why is somebody that is undocumented often in a vulnerable position? A: Undocumented migrants are regarded as a vulnerable group within society. They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations. Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.\n\nAlso, they are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet). They have only a very limited right to assistance and facilities from the government and other agencies. As a result, they can easily get into trouble. The Red Cross provides help to everyone, including undocumented migrants.', 'Q: When is somebody undocumented? A: An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa has expired, or they may never have had one. \n\nThey are mainly migrants who:\n- have had their residence application rejected, for example asylum seekers whose application for asylum has been rejected;\n- have not applied for a residence permit, either for regular residence or asylum;\n- are victims of human trafficking;\n- do not have a work permit, for example domestic workers.\n\nEU citizens do not need to apply for a residence permit to be in the Netherlands legally. Migrants from the EU can therefore never be undocumented."\n', "Q: What is a Dublin claim? A: When somebody asks asylum in the Netherlands, their finger prints will be checked in an EU database. If their fingerprint is registered in another EU country, that country is responsible for proceeding the asylum procedure. In that case somebody gets a Dublin claim and has to return to the EU country where the fingerprint was taken. They cannot get asylum in the Netherlands. This is because according to the EU’s Dublin Regulation, somebody's asylum procedure must be carried out in the first country of arrival. \n\nThe Dublin claim ends after 18 months. So if somebody is capable of staying under the radar for 18 months, then he/ she can request asylum in the Netherlands.\n\nIt is very hard for people with a Dublin Claim to get support. For example often local shelter programs do not provide shelter to people with a Dublin claim.", 'Q: Where can I find information about the programs of the Red Cross for Undocumented Migrants? A: As Red Cross we provide workshops to UM about health care, working rights, healthy habits, clear communication and first aid. We also have a [website](https://helpfulinformation.redcross.nl) with information about local aid organizations and we help people through our WhatsApp Helpline. Besides that people that are UM can also be in our food program or shelter program. This is always through the connection with a partner organization. For more information on our programs, you can have a look at our website: https://www.rodekruis.nl/wat-doen-wij/hulp-in-nederland/ondersteuning-ongedocumenteerde-migranten/', 'Q: Where can I find information about the shelter rights for Undocumented Migrants? A: You can find information about different shelter rights on the website of Stichting Los: https://www.stichtinglos.nl/content/opvang-en-onderdak\n\nIn general people have the right to rent a house, but not from social corperate housing. There is no general right for  ...
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Relevancy (score: 0.8478260869565217, threshold: 0.7, strict: False, evaluation model: gpt-4.1-students (Azure), reason: The score is 0.85 because, although many statements in the retrieval context do not directly address 'how Dublin claimants navigate exclusion from Dutch BBB shelters and municipal aid programs' (e.g., 'does not address how Dublin claimants navigate exclusion'), several relevant statements specifically mention that 'people with a Dublin claim can often not enter the local shelter programs' and that 'it is very hard for people with a Dublin Claim to get support,' which directly relate to the input question. This mix of relevant and irrelevant information justifies a high but not perfect score., error: None)
#
# For test case:
#
#   - input: How do Dublin claimants navigate exclusion from Dutch BBB shelters and municipal aid programs?
#   - actual output: Dublin claimants are often excluded from Dutch BBB shelters and municipal aid programs, as these typically do not accept people with a Dublin claim. To navigate this exclusion, Dublin claimants may try to stay "under the radar" for 18 months, after which their Dublin claim expires and they can reapply for asylum in the Netherlands. During this period, it is very difficult for them to access official support or shelter, so they often rely on informal networks, local support organizations, or emergency aid provided by NGOs like the Red Cross. However, access to shelter and assistance remains extremely limited for this group.
#   - expected output: Dublin claimants are often excluded from Dutch BBB shelters and municipal aid programs, as these typically do not accept people with a Dublin claim. To navigate this exclusion, Dublin claimants may try to stay "under the radar" for 18 months, after which their Dublin claim expires and they can reapply for asylum in the Netherlands. During this period, it is very difficult for them to access official support or shelter, so they often rely on informal networks, local support organizations, or emergency aid provided by NGOs like the Red Cross. However, access to shelter and assistance remains extremely limited for this group.
#   - context: ['Q: What are relevant websites with information about / for UM? A: \n* On the website of **LOS** you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang. \n* On the website **Helpful Information** from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/', 'Q: Why is somebody that is undocumented often in a vulnerable position? A: Undocumented migrants are regarded as a vulnerable group within society. They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations. Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.\n\nAlso, they are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet). They have only a very limited right to assistance and facilities from the government and other agencies. As a result, they can easily get into trouble. The Red Cross provides help to everyone, including undocumented migrants.', 'Q: When is somebody undocumented? A: An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa has expired, or they may never have had one. \n\nThey are mainly migrants who:\n- have had their residence application rejected, for example asylum seekers whose application for asylum has been rejected;\n- have not applied for a residence permit, either for regular residence or asylum;\n- are victims of human trafficking;\n- do not have a work permit, for example domestic workers.\n\nEU citizens do not need to apply for a residence permit to be in the Netherlands legally. Migrants from the EU can therefore never be undocumented."\n', "Q: What is a Dublin claim? A: When somebody asks asylum in the Netherlands, their finger prints will be checked in an EU database. If their fingerprint is registered in another EU country, that country is responsible for proceeding the asylum procedure. In that case somebody gets a Dublin claim and has to return to the EU country where the fingerprint was taken. They cannot get asylum in the Netherlands. This is because according to the EU’s Dublin Regulation, somebody's asylum procedure must be carried out in the first country of arrival. \n\nThe Dublin claim ends after 18 months. So if somebody is capable of staying under the radar for 18 months, then he/ she can request asylum in the Netherlands.\n\nIt is very hard for people with a Dublin Claim to get support. For example often local shelter programs do not provide shelter to people with a Dublin claim.", 'Q: Where can I find information about the programs of the Red Cross for Undocumented Migrants? A: As Red Cross we provide workshops to UM about health care, working rights, healthy habits, clear communication and first aid. We also have a [website](https://helpfulinformation.redcross.nl) with information about local aid organizations and we help people through our WhatsApp Helpline. Besides that people that are UM can also be in our food program or shelter program. This is always through the connection with a partner organization. For more information on our programs, you can have a look at our website: https://www.rodekruis.nl/wat-doen-wij/hulp-in-nederland/ondersteuning-ongedocumenteerde-migranten/', 'Q: Where can I find information about the shelter rights for Undocumented Migrants? A: You can find information about different shelter rights on the website of Stichting Los: https://www.stichtinglos.nl/content/opvang-en-onderdak\n\nIn general people have the right to rent a house, but not from social corperate housing. There is no general right for shelter fo ...
#   - retrieval context: ['Q: What are relevant websites with information about / for UM? A: \n* On the website of **LOS** you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang. \n* On the website **Helpful Information** from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/', 'Q: Why is somebody that is undocumented often in a vulnerable position? A: Undocumented migrants are regarded as a vulnerable group within society. They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations. Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.\n\nAlso, they are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet). They have only a very limited right to assistance and facilities from the government and other agencies. As a result, they can easily get into trouble. The Red Cross provides help to everyone, including undocumented migrants.', 'Q: When is somebody undocumented? A: An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa has expired, or they may never have had one. \n\nThey are mainly migrants who:\n- have had their residence application rejected, for example asylum seekers whose application for asylum has been rejected;\n- have not applied for a residence permit, either for regular residence or asylum;\n- are victims of human trafficking;\n- do not have a work permit, for example domestic workers.\n\nEU citizens do not need to apply for a residence permit to be in the Netherlands legally. Migrants from the EU can therefore never be undocumented."\n', "Q: What is a Dublin claim? A: When somebody asks asylum in the Netherlands, their finger prints will be checked in an EU database. If their fingerprint is registered in another EU country, that country is responsible for proceeding the asylum procedure. In that case somebody gets a Dublin claim and has to return to the EU country where the fingerprint was taken. They cannot get asylum in the Netherlands. This is because according to the EU’s Dublin Regulation, somebody's asylum procedure must be carried out in the first country of arrival. \n\nThe Dublin claim ends after 18 months. So if somebody is capable of staying under the radar for 18 months, then he/ she can request asylum in the Netherlands.\n\nIt is very hard for people with a Dublin Claim to get support. For example often local shelter programs do not provide shelter to people with a Dublin claim.", 'Q: Where can I find information about the programs of the Red Cross for Undocumented Migrants? A: As Red Cross we provide workshops to UM about health care, working rights, healthy habits, clear communication and first aid. We also have a [website](https://helpfulinformation.redcross.nl) with information about local aid organizations and we help people through our WhatsApp Helpline. Besides that people that are UM can also be in our food program or shelter program. This is always through the connection with a partner organization. For more information on our programs, you can have a look at our website: https://www.rodekruis.nl/wat-doen-wij/hulp-in-nederland/ondersteuning-ongedocumenteerde-migranten/', 'Q: Where can I find information about the shelter rights for Undocumented Migrants? A: You can find information about different shelter rights on the website of Stichting Los: https://www.stichtinglos.nl/content/opvang-en-onderdak\n\nIn general people have the right to rent a house, but not from social corperate housing. There is no general right for  ...
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Relevancy (score: 0.8205128205128205, threshold: 0.7, strict: False, evaluation model: gpt-4.1-students (Azure), reason: The score is 0.82 because, while many statements are highly relevant (e.g., 'On the website of LOS you can find information about support organizations' and 'On the website Helpful Information from the Red Cross you can find information about local organizations in different cities'), there are also several statements that do not address where to find info about support organizations or shelters for UM, such as 'This statement explains why undocumented migrants are vulnerable, but does not provide information about support organizations or shelters for UM, nor local options.', error: None)
#
# For test case:
#
#   - input: Where can I find info about support orgs and shelters for UM, incl. local options?
#   - actual output: You can find information about support organizations and shelters for undocumented migrants (UM), including local options, on the Stichting LOS website: https://www.stichtinglos.nl/content/organisaties and for shelters: https://www.stichtinglos.nl/noodopvang. Additionally, the Red Cross Helpful Information website provides details about local organizations in different cities: https://helpfulinformation.redcross.nl/.
#   - expected output: You can find information about support organizations and shelters for undocumented migrants (UM), including local options, on the Stichting LOS website: https://www.stichtinglos.nl/content/organisaties and for shelters: https://www.stichtinglos.nl/noodopvang. Additionally, the Red Cross Helpful Information website provides details about local organizations in different cities: https://helpfulinformation.redcross.nl/.
#   - context: ['Q: What are relevant websites with information about / for UM? A: \n* On the website of **LOS** you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang. \n* On the website **Helpful Information** from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/', 'Q: Why is somebody that is undocumented often in a vulnerable position? A: Undocumented migrants are regarded as a vulnerable group within society. They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations. Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.\n\nAlso, they are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet). They have only a very limited right to assistance and facilities from the government and other agencies. As a result, they can easily get into trouble. The Red Cross provides help to everyone, including undocumented migrants.', 'Q: When is somebody undocumented? A: An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa has expired, or they may never have had one. \n\nThey are mainly migrants who:\n- have had their residence application rejected, for example asylum seekers whose application for asylum has been rejected;\n- have not applied for a residence permit, either for regular residence or asylum;\n- are victims of human trafficking;\n- do not have a work permit, for example domestic workers.\n\nEU citizens do not need to apply for a residence permit to be in the Netherlands legally. Migrants from the EU can therefore never be undocumented."\n', "Q: What is a Dublin claim? A: When somebody asks asylum in the Netherlands, their finger prints will be checked in an EU database. If their fingerprint is registered in another EU country, that country is responsible for proceeding the asylum procedure. In that case somebody gets a Dublin claim and has to return to the EU country where the fingerprint was taken. They cannot get asylum in the Netherlands. This is because according to the EU’s Dublin Regulation, somebody's asylum procedure must be carried out in the first country of arrival. \n\nThe Dublin claim ends after 18 months. So if somebody is capable of staying under the radar for 18 months, then he/ she can request asylum in the Netherlands.\n\nIt is very hard for people with a Dublin Claim to get support. For example often local shelter programs do not provide shelter to people with a Dublin claim.", 'Q: Where can I find information about the programs of the Red Cross for Undocumented Migrants? A: As Red Cross we provide workshops to UM about health care, working rights, healthy habits, clear communication and first aid. We also have a [website](https://helpfulinformation.redcross.nl) with information about local aid organizations and we help people through our WhatsApp Helpline. Besides that people that are UM can also be in our food program or shelter program. This is always through the connection with a partner organization. For more information on our programs, you can have a look at our website: https://www.rodekruis.nl/wat-doen-wij/hulp-in-nederland/ondersteuning-ongedocumenteerde-migranten/', 'Q: Where can I find information about the shelter rights for Undocumented Migrants? A: You can find information about different shelter rights on the website of Stichting Los: https://www.stichtinglos.nl/content/opvang-en-onderdak\n\nIn general people have the right to rent a house, but not from social corperate housing. There is no general right for shelter fo ...
#   - retrieval context: ['Q: What are relevant websites with information about / for UM? A: \n* On the website of **LOS** you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang. \n* On the website **Helpful Information** from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/', 'Q: Why is somebody that is undocumented often in a vulnerable position? A: Undocumented migrants are regarded as a vulnerable group within society. They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations. Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.\n\nAlso, they are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet). They have only a very limited right to assistance and facilities from the government and other agencies. As a result, they can easily get into trouble. The Red Cross provides help to everyone, including undocumented migrants.', 'Q: When is somebody undocumented? A: An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa has expired, or they may never have had one. \n\nThey are mainly migrants who:\n- have had their residence application rejected, for example asylum seekers whose application for asylum has been rejected;\n- have not applied for a residence permit, either for regular residence or asylum;\n- are victims of human trafficking;\n- do not have a work permit, for example domestic workers.\n\nEU citizens do not need to apply for a residence permit to be in the Netherlands legally. Migrants from the EU can therefore never be undocumented."\n', "Q: What is a Dublin claim? A: When somebody asks asylum in the Netherlands, their finger prints will be checked in an EU database. If their fingerprint is registered in another EU country, that country is responsible for proceeding the asylum procedure. In that case somebody gets a Dublin claim and has to return to the EU country where the fingerprint was taken. They cannot get asylum in the Netherlands. This is because according to the EU’s Dublin Regulation, somebody's asylum procedure must be carried out in the first country of arrival. \n\nThe Dublin claim ends after 18 months. So if somebody is capable of staying under the radar for 18 months, then he/ she can request asylum in the Netherlands.\n\nIt is very hard for people with a Dublin Claim to get support. For example often local shelter programs do not provide shelter to people with a Dublin claim.", 'Q: Where can I find information about the programs of the Red Cross for Undocumented Migrants? A: As Red Cross we provide workshops to UM about health care, working rights, healthy habits, clear communication and first aid. We also have a [website](https://helpfulinformation.redcross.nl) with information about local aid organizations and we help people through our WhatsApp Helpline. Besides that people that are UM can also be in our food program or shelter program. This is always through the connection with a partner organization. For more information on our programs, you can have a look at our website: https://www.rodekruis.nl/wat-doen-wij/hulp-in-nederland/ondersteuning-ongedocumenteerde-migranten/', 'Q: Where can I find information about the shelter rights for Undocumented Migrants? A: You can find information about different shelter rights on the website of Stichting Los: https://www.stichtinglos.nl/content/opvang-en-onderdak\n\nIn general people have the right to rent a house, but not from social corperate housing. There is no general right for  ...
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Contextual Relevancy (score: 0.4772727272727273, threshold: 0.7, strict: False, evaluation model: gpt-4.1-students (Azure), reason: The score is 0.48 because, while the relevant statements explain that 'people with a Dublin claim can often not enter the local shelter programs' and that 'the Dublin claim ends after 18 months,' none address the specific scenario of a 36-month Dublin claim or its effect on UM's asylum and shelter options, as highlighted by the irrelevancy reasons: 'does not address how a 36-month Dublin claim would affect UM's asylum and shelter options.', error: None)
#
# For test case:
#
#   - input: If a Dublin claim lasted 36 months, how would this affect UM's asylum and shelter options?
#   - actual output: If a Dublin claim lasted 36 months instead of 18, undocumented migrants (UM) would have to stay under the radar for a much longer period before being able to request asylum in the Netherlands. This would increase their vulnerability and make it even harder to access shelter, as people with a Dublin claim are generally not allowed in local shelter programs like BBB or municipality shelters. Extending the Dublin claim period would therefore significantly limit both their asylum and shelter options, making their situation more difficult.
#   - expected output: If a Dublin claim lasted 36 months instead of 18, undocumented migrants (UM) would have to stay under the radar for a much longer period before being able to request asylum in the Netherlands. This would increase their vulnerability and make it even harder to access shelter, as people with a Dublin claim are generally not allowed in local shelter programs like BBB or municipality shelters. Extending the Dublin claim period would therefore significantly limit both their asylum and shelter options, making their situation more difficult.
#   - context: ['Q: What are relevant websites with information about / for UM? A: \n* On the website of **LOS** you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang. \n* On the website **Helpful Information** from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/', 'Q: Why is somebody that is undocumented often in a vulnerable position? A: Undocumented migrants are regarded as a vulnerable group within society. They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations. Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.\n\nAlso, they are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet). They have only a very limited right to assistance and facilities from the government and other agencies. As a result, they can easily get into trouble. The Red Cross provides help to everyone, including undocumented migrants.', 'Q: When is somebody undocumented? A: An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa has expired, or they may never have had one. \n\nThey are mainly migrants who:\n- have had their residence application rejected, for example asylum seekers whose application for asylum has been rejected;\n- have not applied for a residence permit, either for regular residence or asylum;\n- are victims of human trafficking;\n- do not have a work permit, for example domestic workers.\n\nEU citizens do not need to apply for a residence permit to be in the Netherlands legally. Migrants from the EU can therefore never be undocumented."\n', "Q: What is a Dublin claim? A: When somebody asks asylum in the Netherlands, their finger prints will be checked in an EU database. If their fingerprint is registered in another EU country, that country is responsible for proceeding the asylum procedure. In that case somebody gets a Dublin claim and has to return to the EU country where the fingerprint was taken. They cannot get asylum in the Netherlands. This is because according to the EU’s Dublin Regulation, somebody's asylum procedure must be carried out in the first country of arrival. \n\nThe Dublin claim ends after 18 months. So if somebody is capable of staying under the radar for 18 months, then he/ she can request asylum in the Netherlands.\n\nIt is very hard for people with a Dublin Claim to get support. For example often local shelter programs do not provide shelter to people with a Dublin claim.", 'Q: Where can I find information about the programs of the Red Cross for Undocumented Migrants? A: As Red Cross we provide workshops to UM about health care, working rights, healthy habits, clear communication and first aid. We also have a [website](https://helpfulinformation.redcross.nl) with information about local aid organizations and we help people through our WhatsApp Helpline. Besides that people that are UM can also be in our food program or shelter program. This is always through the connection with a partner organization. For more information on our programs, you can have a look at our website: https://www.rodekruis.nl/wat-doen-wij/hulp-in-nederland/ondersteuning-ongedocumenteerde-migranten/', 'Q: Where can I find information about the shelter rights for Undocumented Migrants? A: You can find information about different shelter rights on the website of Stichting Los: https://www.stichtinglos.nl/content/opvang-en-onderdak\n\nIn general people have the right to rent a house, but not from social corperate housing. There is no general right for shelter fo ...
#   - retrieval context: ['Q: What are relevant websites with information about / for UM? A: \n* On the website of **LOS** you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang. \n* On the website **Helpful Information** from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/', 'Q: Why is somebody that is undocumented often in a vulnerable position? A: Undocumented migrants are regarded as a vulnerable group within society. They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations. Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.\n\nAlso, they are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet). They have only a very limited right to assistance and facilities from the government and other agencies. As a result, they can easily get into trouble. The Red Cross provides help to everyone, including undocumented migrants.', 'Q: When is somebody undocumented? A: An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa has expired, or they may never have had one. \n\nThey are mainly migrants who:\n- have had their residence application rejected, for example asylum seekers whose application for asylum has been rejected;\n- have not applied for a residence permit, either for regular residence or asylum;\n- are victims of human trafficking;\n- do not have a work permit, for example domestic workers.\n\nEU citizens do not need to apply for a residence permit to be in the Netherlands legally. Migrants from the EU can therefore never be undocumented."\n', "Q: What is a Dublin claim? A: When somebody asks asylum in the Netherlands, their finger prints will be checked in an EU database. If their fingerprint is registered in another EU country, that country is responsible for proceeding the asylum procedure. In that case somebody gets a Dublin claim and has to return to the EU country where the fingerprint was taken. They cannot get asylum in the Netherlands. This is because according to the EU’s Dublin Regulation, somebody's asylum procedure must be carried out in the first country of arrival. \n\nThe Dublin claim ends after 18 months. So if somebody is capable of staying under the radar for 18 months, then he/ she can request asylum in the Netherlands.\n\nIt is very hard for people with a Dublin Claim to get support. For example often local shelter programs do not provide shelter to people with a Dublin claim.", 'Q: Where can I find information about the programs of the Red Cross for Undocumented Migrants? A: As Red Cross we provide workshops to UM about health care, working rights, healthy habits, clear communication and first aid. We also have a [website](https://helpfulinformation.redcross.nl) with information about local aid organizations and we help people through our WhatsApp Helpline. Besides that people that are UM can also be in our food program or shelter program. This is always through the connection with a partner organization. For more information on our programs, you can have a look at our website: https://www.rodekruis.nl/wat-doen-wij/hulp-in-nederland/ondersteuning-ongedocumenteerde-migranten/', 'Q: Where can I find information about the shelter rights for Undocumented Migrants? A: You can find information about different shelter rights on the website of Stichting Los: https://www.stichtinglos.nl/content/opvang-en-onderdak\n\nIn general people have the right to rent a house, but not from social corperate housing. There is no general right for  ...
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Contextual Relevancy (score: 0.6382978723404256, threshold: 0.7, strict: False, evaluation model: gpt-4.1-students (Azure), reason: The score is 0.64 because, while most statements in the retrieval context 'provide website resources for support organizations and shelters, but do not discuss the challenges faced by stateless individuals,' several statements are relevant, such as 'Undocumented migrants are regarded as a vulnerable group within society,' and 'They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations.' This partial overlap explains the moderate score., error: None)
#
# For test case:
#
#   - input: Examine the challenges faced by stateless individuals lacking any legal residency or nationality documentation.
#   - actual output: Stateless individuals without legal residency or nationality documentation face significant challenges. They have no recognized legal status, which means they cannot access basic rights such as social benefits, health insurance, or legal employment. This makes them highly vulnerable to exploitation by employers, landlords, or traffickers. They are often excluded from most government assistance and shelter programs, and finding housing is extremely difficult since most shelters require a residence permit. Their lack of documentation leaves them in unsafe or unhealthy situations and makes it easy for them to get into trouble or be taken advantage of.
#   - expected output: Stateless individuals without legal residency or nationality documentation face significant challenges. They have no recognized legal status, which means they cannot access basic rights such as social benefits, health insurance, or legal employment. This makes them highly vulnerable to exploitation by employers, landlords, or traffickers. They are often excluded from most government assistance and shelter programs, and finding housing is extremely difficult since most shelters require a residence permit. Their lack of documentation leaves them in unsafe or unhealthy situations and makes it easy for them to get into trouble or be taken advantage of.
#   - context: ['Q: What are relevant websites with information about / for UM? A: \n* On the website of **LOS** you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang. \n* On the website **Helpful Information** from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/', 'Q: Why is somebody that is undocumented often in a vulnerable position? A: Undocumented migrants are regarded as a vulnerable group within society. They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations. Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.\n\nAlso, they are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet). They have only a very limited right to assistance and facilities from the government and other agencies. As a result, they can easily get into trouble. The Red Cross provides help to everyone, including undocumented migrants.', 'Q: When is somebody undocumented? A: An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa has expired, or they may never have had one. \n\nThey are mainly migrants who:\n- have had their residence application rejected, for example asylum seekers whose application for asylum has been rejected;\n- have not applied for a residence permit, either for regular residence or asylum;\n- are victims of human trafficking;\n- do not have a work permit, for example domestic workers.\n\nEU citizens do not need to apply for a residence permit to be in the Netherlands legally. Migrants from the EU can therefore never be undocumented."\n', "Q: What is a Dublin claim? A: When somebody asks asylum in the Netherlands, their finger prints will be checked in an EU database. If their fingerprint is registered in another EU country, that country is responsible for proceeding the asylum procedure. In that case somebody gets a Dublin claim and has to return to the EU country where the fingerprint was taken. They cannot get asylum in the Netherlands. This is because according to the EU’s Dublin Regulation, somebody's asylum procedure must be carried out in the first country of arrival. \n\nThe Dublin claim ends after 18 months. So if somebody is capable of staying under the radar for 18 months, then he/ she can request asylum in the Netherlands.\n\nIt is very hard for people with a Dublin Claim to get support. For example often local shelter programs do not provide shelter to people with a Dublin claim.", 'Q: Where can I find information about the programs of the Red Cross for Undocumented Migrants? A: As Red Cross we provide workshops to UM about health care, working rights, healthy habits, clear communication and first aid. We also have a [website](https://helpfulinformation.redcross.nl) with information about local aid organizations and we help people through our WhatsApp Helpline. Besides that people that are UM can also be in our food program or shelter program. This is always through the connection with a partner organization. For more information on our programs, you can have a look at our website: https://www.rodekruis.nl/wat-doen-wij/hulp-in-nederland/ondersteuning-ongedocumenteerde-migranten/', 'Q: Where can I find information about the shelter rights for Undocumented Migrants? A: You can find information about different shelter rights on the website of Stichting Los: https://www.stichtinglos.nl/content/opvang-en-onderdak\n\nIn general people have the right to rent a house, but not from social corperate housing. There is no general right for shelter fo ...
# ...
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Contextual Relevancy (score: 0.16666666666666666, threshold: 0.7, strict: False, evaluation model: gpt-4.1-students (Azure), reason: The score is 0.17 because most statements are about clothing distribution or finding donation containers, not Sympany's processing methods, though one relevant statement notes Red Cross cooperates with Sympany for collection and repurposing., error: None)
#
# For test case:
#
#   - input: How does Sympany process and repurpose clothing collected from Red Cross donation containers?
#   - actual output: Sympany collects clothing from Red Cross donation containers, sorts it, and then repurposes it by either reselling wearable items in second-hand shops or recycling unusable textiles into new products. This process helps reduce waste and supports sustainable clothing use. For more information, visit https://www.sympany.nl/.
#   - expected output: Sympany collects clothing from Red Cross donation containers, sorts it, and then repurposes it by either reselling wearable items in second-hand shops or recycling unusable textiles into new products. This process helps reduce waste and supports sustainable clothing use. For more information, visit https://www.sympany.nl/.
#   - context: ["Q: Does the Red Cross provide clothing? A: We don't provide clohting to individuals, only to shelter locations. Therefore, we cannot help somebody on our helpline directly, but we can only refer them to options that are found on HIA or by googling. Always check where somebody lives so you can give them the option most closeby. Find a list of options per city on HIA: https://helpfulinformation.redcross.nl/ ", 'Q: Can I donate clothing to the Red Cross? A: The Red Cross cooperates with Sympany for collection of clothing donations and repurposing them. Via this link you can find the closest donationcontainer: https://www.sympany.nl/']
#   - retrieval context: ["Q: Does the Red Cross provide clothing? A: We don't provide clohting to individuals, only to shelter locations. Therefore, we cannot help somebody on our helpline directly, but we can only refer them to options that are found on HIA or by googling. Always check where somebody lives so you can give them the option most closeby. Find a list of options per city on HIA: https://helpfulinformation.redcross.nl/ ", 'Q: Can I donate clothing to the Red Cross? A: The Red Cross cooperates with Sympany for collection of clothing donations and repurposing them. Via this link you can find the closest donationcontainer: https://www.sympany.nl/']
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Contextual Relevancy (score: 0.16666666666666666, threshold: 0.7, strict: False, evaluation model: gpt-4.1-students (Azure), reason: The score is 0.17 because, although 'The Red Cross cooperates with Sympany for collection of clothing donations and repurposing them' is relevant, most statements 'do not mention clothing collection or repurposing via containers, nor any cooperation with Sympany.', error: None)
#
# For test case:
#
#   - input: How does the Red Cross, in cooperation with Sympany, collect and repurpose clothing donations via containers?
#   - actual output: The Red Cross works with Sympany to collect clothing donations through designated containers. Donors can find the nearest container using https://www.sympany.nl/. Sympany then collects and repurposes the donated clothing.
#   - expected output: The Red Cross works with Sympany to collect clothing donations through designated containers. Donors can find the nearest container using https://www.sympany.nl/. Sympany then collects and repurposes the donated clothing.
#   - context: ["Q: Does the Red Cross provide clothing? A: We don't provide clohting to individuals, only to shelter locations. Therefore, we cannot help somebody on our helpline directly, but we can only refer them to options that are found on HIA or by googling. Always check where somebody lives so you can give them the option most closeby. Find a list of options per city on HIA: https://helpfulinformation.redcross.nl/ ", 'Q: Can I donate clothing to the Red Cross? A: The Red Cross cooperates with Sympany for collection of clothing donations and repurposing them. Via this link you can find the closest donationcontainer: https://www.sympany.nl/']
#   - retrieval context: ["Q: Does the Red Cross provide clothing? A: We don't provide clohting to individuals, only to shelter locations. Therefore, we cannot help somebody on our helpline directly, but we can only refer them to options that are found on HIA or by googling. Always check where somebody lives so you can give them the option most closeby. Find a list of options per city on HIA: https://helpfulinformation.redcross.nl/ ", 'Q: Can I donate clothing to the Red Cross? A: The Red Cross cooperates with Sympany for collection of clothing donations and repurposing them. Via this link you can find the closest donationcontainer: https://www.sympany.nl/']
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Relevancy (score: 0.8333333333333334, threshold: 0.7, strict: False, evaluation model: gpt-4.1-students (Azure), reason: The score is 0.83 because while most statements like 'Find a list of options per city on HIA' and 'Via this link you can find the closest donationcontainer: https://www.sympany.nl/' are directly relevant, there is some minor irrelevancy such as 'only to shelter locations' which does not address the input question., error: None)
#
# For test case:
#
#   - input: How can Sympany's partnership and HIA city lists help locate nearby clothing donation containers?
#   - actual output: Sympany's partnership with the Red Cross allows you to find nearby clothing donation containers using their website: https://www.sympany.nl/. Additionally, the HIA city lists (https://helpfulinformation.redcross.nl/) provide location-specific options, helping you identify the closest donation points in your area.
#   - expected output: Sympany's partnership with the Red Cross allows you to find nearby clothing donation containers using their website: https://www.sympany.nl/. Additionally, the HIA city lists (https://helpfulinformation.redcross.nl/) provide location-specific options, helping you identify the closest donation points in your area.
#   - context: ["Q: Does the Red Cross provide clothing? A: We don't provide clohting to individuals, only to shelter locations. Therefore, we cannot help somebody on our helpline directly, but we can only refer them to options that are found on HIA or by googling. Always check where somebody lives so you can give them the option most closeby. Find a list of options per city on HIA: https://helpfulinformation.redcross.nl/ ", 'Q: Can I donate clothing to the Red Cross? A: The Red Cross cooperates with Sympany for collection of clothing donations and repurposing them. Via this link you can find the closest donationcontainer: https://www.sympany.nl/']
#   - retrieval context: ["Q: Does the Red Cross provide clothing? A: We don't provide clohting to individuals, only to shelter locations. Therefore, we cannot help somebody on our helpline directly, but we can only refer them to options that are found on HIA or by googling. Always check where somebody lives so you can give them the option most closeby. Find a list of options per city on HIA: https://helpfulinformation.redcross.nl/ ", 'Q: Can I donate clothing to the Red Cross? A: The Red Cross cooperates with Sympany for collection of clothing donations and repurposing them. Via this link you can find the closest donationcontainer: https://www.sympany.nl/']
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Contextual Relevancy (score: 0.3333333333333333, threshold: 0.7, strict: False, evaluation model: gpt-4.1-students (Azure), reason: The score is 0.33 because, although the statement 'The Red Cross does not provide clothing to individuals, only to shelter locations.' is directly relevant, most of the retrieval context discusses referral logistics and donation collection rather than answering the input question., error: None)
#
# For test case:
#
#   - input: Does the Red Cross distribute clothing directly to individuals, or only to shelter locations?
#   - actual output: The Red Cross only provides clothing to shelter locations, not directly to individuals.
#   - expected output: The Red Cross only provides clothing to shelter locations, not directly to individuals.
#   - context: ["Q: Does the Red Cross provide clothing? A: We don't provide clohting to individuals, only to shelter locations. Therefore, we cannot help somebody on our helpline directly, but we can only refer them to options that are found on HIA or by googling. Always check where somebody lives so you can give them the option most closeby. Find a list of options per city on HIA: https://helpfulinformation.redcross.nl/ ", 'Q: Can I donate clothing to the Red Cross? A: The Red Cross cooperates with Sympany for collection of clothing donations and repurposing them. Via this link you can find the closest donationcontainer: https://www.sympany.nl/']
#   - retrieval context: ["Q: Does the Red Cross provide clothing? A: We don't provide clohting to individuals, only to shelter locations. Therefore, we cannot help somebody on our helpline directly, but we can only refer them to options that are found on HIA or by googling. Always check where somebody lives so you can give them the option most closeby. Find a list of options per city on HIA: https://helpfulinformation.redcross.nl/ ", 'Q: Can I donate clothing to the Red Cross? A: The Red Cross cooperates with Sympany for collection of clothing donations and repurposing them. Via this link you can find the closest donationcontainer: https://www.sympany.nl/']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Contextual Relevancy: 14.71% pass rate
#
# ======================================================================
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=101277;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 54.84s | token cost: None)
# » Test Results (102 total tests):
#    » Pass Rate: 14.71% | Passed: 15 | Failed: 87
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.
# EvaluationResult(test_results=[TestResult(name='test_case_2', success=False, metrics_data=[MetricData(name='Contextual Relevancy', threshold=0.7, success=False, score=0.6739130434782609, reason="The score is 0.67 because, although the relevant statements highlight that 'undocumented migrants are regarded as a vulnerable group within society' and face risks like 'exploitation at the hands of bad employers, slum landlords or human traffickers' and 'housing is a very big challenge,' most of the retrieval context only provides procedural information or resources, which 'does not address the risks UM might face if they lost access to all support orgs.'", strict_mode=False, evaluation_model='gpt-4.1-students (Azure)', error=None, evaluation_cost=None, verbose_logs='Verdicts:\n[\n    {\n        "verdicts": [\n            {\n                "statement": "On the website of LOS you can find information about support organizations: https://www.stichtinglos.nl/content/organisaties and shelters in the Netherlands: https://www.stichtinglos.nl/noodopvang.",\n                "verdict": "no",\n                "reason": "The statement provides links to information about support organizations and shelters, but does not address the risks UM might face if they lost access to all support orgs."\n            },\n            {\n                "statement": "On the website Helpful Information from the Red Cross you can find information about local organizations in different cities: https://helpfulinformation.redcross.nl/",\n                "verdict": "no",\n                "reason": "The statement only provides a resource for finding local organizations, not about the risks UM might face if they lost access to all support orgs."\n            }\n        ]\n    },\n    {\n        "verdicts": [\n            {\n                "statement": "Undocumented migrants are regarded as a vulnerable group within society.",\n                "verdict": "yes",\n                "reason": null\n            },\n            {\n                "statement": "They do not have a residence permit and, because of their limited rights, they quickly find themselves in unsafe or unhealthy situations.",\n                "verdict": "yes",\n                "reason": null\n            },\n            {\n                "statement": "Because of their vulnerable position, they are easy prey for exploitation at the hands of bad employers, slum landlords or human traffickers.",\n                "verdict": "yes",\n                "reason": null\n            },\n            {\n                "statement": "They are not entitled to social benefits and cannot take out health insurance (the 1998 Dutch Benefit Entitlement (Residence Status) Act; Koppelingswet).",\n                "verdict": "yes",\n                "reason": null\n            },\n            {\n                "statement": "They have only a very limited right to assistance and facilities from the government and other agencies.",\n                "verdict": "yes",\n                "reason": null\n            },\n            {\n                "statement": "As a result, they can easily get into trouble.",\n                "verdict": "yes",\n                "reason": null\n            },\n            {\n                "statement": "The Red Cross provides help to everyone, including undocumented migrants.",\n                "verdict": "no",\n                "reason": "The statement \'The Red Cross provides help to everyone, including undocumented migrants.\' is not relevant to the risks UM might face if they lost access to all support orgs, as it describes an exception (continued support) rather than a risk arising from lack of support."\n            }\n        ]\n    },\n    {\n        "verdicts": [\n            {\n                "statement": "An undocumented migrant is a person who has no right of residence in a country. They have no documents confirming a right of residence, such as a visa. Their work, residence or study visa  ...
